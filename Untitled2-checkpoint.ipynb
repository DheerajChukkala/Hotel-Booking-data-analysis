# %% [markdown]
# # Importing Essential Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset and dropping Variables

# %%
dataset=pd.read_csv('hotel_booking.csv')
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
dataset.shape
# Out:
# (119390, 36)

# %%
dataset.drop(['name','email','phone-number','credit_card'],axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (119390, 32)

# %%
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning and EDA

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
dataset['reservation_status_date']=pd.to_datetime(dataset['reservation_status_date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
dataset.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in dataset.describe(include='object').columns:
    print(col)
    print(dataset[col].unique())
    print('_'* 80)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ________________________________________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ________________________________________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ________________________________________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
dataset.drop(['company','agent'],axis=1,inplace=True)
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
dataset['adr'].plot(kind='box')

# %%
dataset=dataset[dataset['adr']<5000]

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualizations

# %%
cancelled_perc = dataset['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(5,4))
plt.title('Count of Reservation status ')
plt.bar(['Not cancelled','Cancelled'],dataset['is_canceled'].value_counts(),edgecolor='r',width=0.5)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(8,6))
ax1=sns.countplot(x='hotel',hue='is_canceled',data=dataset,palette='inferno')
legend_labels,_=ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status of different hotels',size=20)
plt.xlabel('Hotel')
plt.ylabel('No of Reservations')
plt.legend(['Not cancelled','Cancelled'])
plt.show()
#The get_legend_handles_labels() function retrieves the handles and labels of the legend items from the ax1 object. 
#The handles represent the bars or patches in the plot, and the labels correspond to the legend labels.
#The legend() function is then called on ax1 with the bbox_to_anchor parameter set to (1, 1).
#This parameter specifies the coordinates of the legend box's anchor point,which in this case isthetop-right corner of the plot.

# %%
Resort_Hotel=dataset[dataset['hotel'] =='Resort Hotel']
Resort_Hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
City_Hotel=dataset[dataset['hotel'] =='City Hotel']
City_Hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
print(Resort_Hotel['adr'].dtypes)
print(City_Hotel['adr'].dtypes)
# Out:
# float64
# float64

# %%
Resort_Hotel=Resort_Hotel.groupby('reservation_status_date')[['adr']].mean()
City_Hotel=City_Hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in city hotel and resort hotel',fontsize=30)
plt.plot(Resort_Hotel.index,Resort_Hotel['adr'],label='Resort Hotel')
plt.plot(City_Hotel.index,City_Hotel['adr'],label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
dataset['Month']=dataset['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='Month',hue='is_canceled',data=dataset,palette='bright')
legend_labels,_=ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status per Month',size=20)
plt.xlabel('Month')
plt.ylabel('No of Reservations')
plt.legend(['Not cancelled','Cancelled'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month',fontsize=20)
sns.barplot('Month','adr',data=dataset[dataset['is_canceled'] == 1].groupby('Month')[['adr']].sum().reset_index())
plt.show()

# %%
cancelled_data= dataset[dataset['is_canceled']==1]
top_10_country=cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(10,10))
plt.title('Top 10 countries with reservations cancelled')
plt.pie(top_10_country, autopct = '%.2f',labels=top_10_country.index)
plt.show()

# %%
# Portugal has the most cancellations in all the countries

# %%
dataset['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
# The Majority clients are coming from Online TA

# %%
cancelled_data_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_data_adr.reset_index(inplace=True)
cancelled_data_adr.sort_values('reservation_status_date',inplace=True)

Not_cancelled_data=dataset[dataset['is_canceled'] == 0]
Not_cancelled_data_adr=Not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
Not_cancelled_data_adr.reset_index(inplace=True)
Not_cancelled_data_adr.sort_values('reservation_status_date',inplace=True)

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(Not_cancelled_data_adr['reservation_status_date'],Not_cancelled_data_adr['adr'],label='Not cancelled')
plt.plot(cancelled_data_adr['reservation_status_date'],cancelled_data_adr['adr'],label='cancelled')


plt.legend()
plt.show()

# %%
cancelled_data_adr=cancelled_data_adr[(cancelled_data_adr['reservation_status_date']>'2016') & (cancelled_data_adr['reservation_status_date']<'2017-09')]
Not_cancelled_data_adr=Not_cancelled_data_adr[(Not_cancelled_data_adr['reservation_status_date']>'2016') & (Not_cancelled_data_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(Not_cancelled_data_adr1['reservation_status_date'],Not_cancelled_data_adr1['adr'],label='Not cancelled')
plt.plot(cancelled_data_adr['reservation_status_date'],cancelled_data_adr['adr'],label='cancelled')
plt.legend(fontsize=20)
plt.show()
